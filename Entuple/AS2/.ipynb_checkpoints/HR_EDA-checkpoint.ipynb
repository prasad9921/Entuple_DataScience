# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 4.14.3

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
d=pd.read_csv('HR_Dataset.csv')

# %%
d.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
d.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
d.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
for i in d:
    if(type(d[i][0])==str):
        print(i)
        print(d[i].value_counts())
        print(50*'-')
# Out:
# Employee_Name
# Bachiochi, Linda     1
# Tannen, Biff         1
# Corleone, Vito       1
# Moumanil, Maliki     1
# Bunbury, Jessica     1
#                     ..
# Latif, Mohammed      1
# Forrest, Alex        1
# Pearson, Randall     1
# Moran, Patrick       1
# Owad, Clinton        1
# Name: Employee_Name, Length: 311, dtype: int64
# --------------------------------------------------
# Position
# Production Technician I         137
# Production Technician II         57
# Area Sales Manager               27
# Production Manager               14
# Software Engineer                10
# IT Support                        8
# Data Analyst                      7
# Sr. Network Engineer              5
# Network Engineer                  5
# Database Administrator            5
# BI Developer                      4
# Administrative Assistant          3
# Accountant I                      3
# Senior BI Developer               3
# Sales Manager                     3
# ...

# %%
fig_dims = (50,8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['Position'],ax=ax)
# Out:
# <AxesSubplot:xlabel='Position', ylabel='count'>

# %%
fig_dims = (10,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['State'],ax=ax)
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
sns.countplot(x=d['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=d['MaritalDesc'])
# Out:
# <AxesSubplot:xlabel='MaritalDesc', ylabel='count'>

# %%
sns.countplot(x=d['CitizenDesc'])
# Out:
# <AxesSubplot:xlabel='CitizenDesc', ylabel='count'>

# %%
sns.countplot(x=d['HispanicLatino'])
# Out:
# <AxesSubplot:xlabel='HispanicLatino', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['RaceDesc'],ax=ax)
# Out:
# <AxesSubplot:xlabel='RaceDesc', ylabel='count'>

# %%
lab=d['TermReason'].unique()
plt.figure(figsize=(10,10))
plt.pie(d['TermReason'].value_counts(),labels=lab,autopct='%1.2f%%',shadow=True)
plt.title('Term Reason')
plt.axis('equal')
plt.show()

# %%
sns.countplot(x=d['EmploymentStatus'])
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='count'>

# %%
lab=d['RecruitmentSource'].unique()
plt.figure(figsize=(10,10))
plt.pie(d['RecruitmentSource'].value_counts(),labels=lab,autopct='%1.2f%%',shadow=True)
plt.title('Recruitment Source')
plt.axis('equal')
plt.show()

# %%
lab=d['Department'].unique()
plt.figure(figsize=(6,6))
plt.pie(d['Department'].value_counts(),labels=lab,autopct='%1.2f%%',shadow=True)
plt.title('Department')
plt.axis('equal')
plt.show()

# %%
sns.countplot(x=d['PerformanceScore'])
# Out:
# <AxesSubplot:xlabel='PerformanceScore', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.hist(x=d['Salary'],bins=50)
plt.xticks(list(range(27500,250001,25000)))
plt.show()

# %%
sns.countplot(x=d['MaritalDesc'],hue=d['Sex'])
# Out:
# <AxesSubplot:xlabel='MaritalDesc', ylabel='count'>

# %%
sns.countplot(x=d['EmploymentStatus'],hue=d['Sex'])
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='count'>

# %%
sns.countplot(x=d['PerformanceScore'],hue=d['Sex'])
# Out:
# <AxesSubplot:xlabel='PerformanceScore', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['EmploymentStatus'],hue=d['MaritalDesc'],ax=ax)
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['RecruitmentSource'],hue=d['PerformanceScore'],ax=ax)
# Out:
# <AxesSubplot:xlabel='RecruitmentSource', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['RecruitmentSource'],hue=d['Department'],ax=ax)
# Out:
# <AxesSubplot:xlabel='RecruitmentSource', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['RecruitmentSource'],hue=d['EmploymentStatus'],ax=ax)
# Out:
# <AxesSubplot:xlabel='RecruitmentSource', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['Department'],hue=d['PerformanceScore'],ax=ax)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['Department'],hue=d['Sex'],ax=ax)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x=d['Department'],hue=d['EmploymentStatus'],ax=ax)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.boxplot(x=d['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
sns.boxplot(x=d['Sex'],y=d['Salary'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Salary'>

# %%
sns.boxplot(x=d['MaritalDesc'],y=d['Salary'])
# Out:
# <AxesSubplot:xlabel='MaritalDesc', ylabel='Salary'>

# %%
sns.boxplot(x=d['EmploymentStatus'],y=d['Salary'])
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='Salary'>

# %%
fig_dims = (15,6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=d['RecruitmentSource'],y=d['Salary'],ax=ax)
# Out:
# <AxesSubplot:xlabel='RecruitmentSource', ylabel='Salary'>

# %%
sns.boxplot(x=d['PerformanceScore'],y=d['Salary'])
# Out:
# <AxesSubplot:xlabel='PerformanceScore', ylabel='Salary'>

# %%
d.iplot(kind='bar',x='PerformanceScore',y='Salary',size=10)
# Out:
# <div>                            <div id="bd09ac95-b070-4c4a-8448-aaa79726cf89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='bar',x='Position',y='Salary',size=10)
# Out:
# <div>                            <div id="3838c7e8-31b0-4c27-9d8a-5f8cdf211eea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='bar',x='Position',y='PerformanceScore',size=10)
# Out:
# <div>                            <div id="1d5ab25c-e391-4dc9-9f8a-ac099341f044" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='bar',x='RecruitmentSource',y='PerformanceScore',size=10)
# Out:
# <div>                            <div id="53703791-3ed2-4e21-8565-93fc18a9a24b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='bar',x='RecruitmentSource',y='Salary',size=10)
# Out:
# <div>                            <div id="6f3432df-58ec-452b-8dd7-f89e56bbfbb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='bar',x='RecruitmentSource',y='Absences',size=10)
# Out:
# <div>                            <div id="a41f45ac-3594-4f3d-9c61-f35eb46fc69f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='bar',x='Position',y='Absences',size=10)
# Out:
# <div>                            <div id="db11159a-719a-48c7-81ac-37bdc71ce087" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='bar',x='Department',y='Absences',size=10)
# Out:
# <div>                            <div id="0259ec27-bf21-47c8-bf2f-ae524994f694" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.style.use('seaborn-whitegrid')
d.hist(bins=20,figsize=(14,10))
plt.show()

# %%
sns.pairplot(d,hue='Sex',palette='coolwarm')
# Out:
# C:\Users\prasa\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
#
# C:\Users\prasa\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.

# %%
plt.figure(figsize=(12,10))
cor=d.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Reds)
plt.show()
